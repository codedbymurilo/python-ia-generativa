# %%
# 1. A matemarica da IA (NumPy)
import numpy as np

print("--- O PROBLEMA DO PYTHON PURO ---")
precos_lista = [100_000,200_00,300_000]

# O Pythn puro não faz a conta, ele apenas duplica os elementos da lista
print("Lista vezes 2:", precos_lista * 2)

print("\n--- A SOLUÇÃO COM NUMPY ---")
# Transformamos a lista em um 'Array' (vetor matemático)
precos_numpy = np.array([100_000,200_000,300_000])

# O NumPy percebe instantaneamente que queremos multiplicar cada número
precos_atualizados = precos_numpy * 2
print("Array vezes 2", precos_atualizados)

print("\n--- COMO A IA VÊ O MUNDO (Matrizes) ----")
# Na IA tudo são números (Matrizes)
matriz_dados = np.array([
    [1,2,3],
    [4,5,6]
])

print(matriz_dados)
# Out:
# --- O PROBLEMA DO PYTHON PURO ---
# Lista vezes 2: [100000, 20000, 300000, 100000, 20000, 300000]
#
# --- A SOLUÇÃO COM NUMPY ---
# Array vezes 2 [200000 400000 600000]
#
# --- COMO A IA VÊ O MUNDO (Matrizes) ----
# [[1 2 3]
#  [4 5 6]]
