# %%
# Conhecendo o Pandas
import pandas as pd

# 1. Criando um dicionário
dados_exemplo = {
    "nome": ["Ana","Bruno","Carlos"],
    "idade": [25,30,22],
    "profissao": ["Professora","Motorista","Estudante"]
}

# 2. Transformando o dicionário em uma tabela (DataFrame)
tabela = pd.DataFrame(dados_exemplo)

print("Pandas organizando os dados em tabela ...")
display(tabela)

# 3. Separando apenas a coluna "idade"
idades = tabela["idade"]
print("\nMostrando apenas a coluna de idades:")
print(idades)
# Out:
# Pandas organizando os dados em tabela ...
#      nome  idade   profissao
# 0     Ana     25  Professora
# 1   Bruno     30   Motorista
# 2  Carlos     22   Estudante
# Mostrando apenas a coluna de idades:
# 0    25
# 1    30
# 2    22
# Name: idade, dtype: int64
